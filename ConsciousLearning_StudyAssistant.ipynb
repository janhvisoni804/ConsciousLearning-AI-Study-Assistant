# %% [markdown]
# <a href="https://colab.research.google.com/github/janhvisoni804/ConsciousLearning-AI-Study-Assistant/blob/main/ConsciousLearning_StudyAssistant.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install --upgrade google-generativeai gTTS
from IPython.display import Audio, display
# Out:
# Requirement already satisfied: google-generativeai in /usr/local/lib/python3.12/dist-packages (0.8.5)
# Requirement already satisfied: gTTS in /usr/local/lib/python3.12/dist-packages (2.5.4)
# Requirement already satisfied: google-ai-generativelanguage==0.6.15 in /usr/local/lib/python3.12/dist-packages (from google-generativeai) (0.6.15)
# Requirement already satisfied: google-api-core in /usr/local/lib/python3.12/dist-packages (from google-generativeai) (2.28.1)
# Requirement already satisfied: google-api-python-client in /usr/local/lib/python3.12/dist-packages (from google-generativeai) (2.187.0)
# Requirement already satisfied: google-auth>=2.15.0 in /usr/local/lib/python3.12/dist-packages (from google-generativeai) (2.43.0)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.12/dist-packages (from google-generativeai) (5.29.5)
# Requirement already satisfied: pydantic in /usr/local/lib/python3.12/dist-packages (from google-generativeai) (2.12.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from google-generativeai) (4.67.1)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.12/dist-packages (from google-generativeai) (4.15.0)
# Requirement already satisfied: proto-plus<2.0.0dev,>=1.22.3 in /usr/local/lib/python3.12/dist-packages (from google-ai-generativelanguage==0.6.15->google-generativeai) (1.26.1)
# Requirement already satisfied: requests<3,>=2.27 in /usr/local/lib/python3.12/dist-packages (from gTTS) (2.32.4)
# Requirement already satisfied: click<8.2,>=7.1 in /usr/local/lib/python3.12/dist-packages (from gTTS) (8.1.8)
# Requirement already satisfied: googleapis-common-protos<2.0.0,>=1.56.2 in /usr/local/lib/python3.12/dist-packages (from google-api-core->google-generativeai) (1.72.0)
# Requirement already satisfied: cachetools<7.0,>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from google-auth>=2.15.0->google-generativeai) (6.2.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.12/dist-packages (from google-auth>=2.15.0->google-generativeai) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.12/dist-packages (from google-auth>=2.15.0->google-generativeai) (4.9.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.27->gTTS) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.27->gTTS) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.27->gTTS) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.27->gTTS) (2025.11.12)
# Requirement already satisfied: httplib2<1.0.0,>=0.19.0 in /usr/local/lib/python3.12/dist-packages (from google-api-python-client->google-generativeai) (0.31.0)
# Requirement already satisfied: google-auth-httplib2<1.0.0,>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from google-api-python-client->google-generativeai) (0.2.1)
# Requirement already satisfied: uritemplate<5,>=3.0.1 in /usr/local/lib/python3.12/dist-packages (from google-api-python-client->google-generativeai) (4.2.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic->google-generativeai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.4 in /usr/local/lib/python3.12/dist-packages (from pydantic->google-generativeai) (2.41.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from pydantic->google-generativeai) (0.4.2)
# Requirement already satisfied: grpcio<2.0.0,>=1.33.2 in /usr/local/lib/python3.12/dist-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-ai-generativelanguage==0.6.15->google-generativeai) (1.76.0)
# Requirement already satisfied: grpcio-status<2.0.0,>=1.33.2 in /usr/local/lib/python3.12/dist-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-ai-generativelanguage==0.6.15->google-generativeai) (1.71.2)
# Requirement already satisfied: pyparsing<4,>=3.0.4 in /usr/local/lib/python3.12/dist-packages (from httplib2<1.0.0,>=0.19.0->google-api-python-client->google-generativeai) (3.2.5)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in /usr/local/lib/python3.12/dist-packages (from pyasn1-modules>=0.2.1->google-auth>=2.15.0->google-generativeai) (0.6.1)

# %%
import os
os.environ["GEMINI_API_KEY"] = "AIzaSyCtNeMR3BX8MQGnvZDKOGtMyrN-zzopEEw"

# %%
# !pip install -q google-generativeai gTTS

# %%
from IPython.display import Audio, display
import google.generativeai as genai
import os

# 🔑 Insert Your Gemini Key
os.environ["GEMINI_API_KEY"] = "AIzaSyCtNeMR3BX8MQGnvZDKOGtMyrN-zzopEEw"

# ✨ Configure Model
genai.configure(api_key=os.environ["GEMINI_API_KEY"])
model = genai.GenerativeModel("models/gemini-2.5-flash")

# 🎧 Text → Speech
def speak(text):
    from gtts import gTTS
    tts = gTTS(text)
    file = "voice.mp3"
    tts.save(file)
    return Audio(file, autoplay=True)

# 🧠 AI Helper
def ask_ai(msg):
    reply = model.generate_content([msg]).text
    return reply

# 💾 Student Memory
profile = {}

# 🤖 Study Agents
def menu():
    print("""
========== ConsciousLearning ==========
1️⃣ Study Plan
2️⃣ Quiz Generator
3️⃣ Explain Topic
4️⃣ Summarize Notes
5️⃣ Exit
=======================================
""")
    choice = input("Choose (1-5): ")

    if choice == "1": return study_plan()
    elif choice == "2": return quiz()
    elif choice == "3": return explain()
    elif choice == "4": return summary()
    else:
        print("\nGoodbye! Keep learning 🌟")
        display(speak("Goodbye! Keep learning."))
        return

def start():
    print("👋 Welcome to ConsciousLearning!")
    print("Which level?\n1 School  2 College  3 Competitive Exams")
    profile["level"] = input("➡ ")

    print("\nEnter subjects comma separated:")
    profile["subjects"] = [s.strip() for s in input("➡ ").split(",")]

    print("\nAll Set! 🚀")
    menu()

def study_plan():
    subjects = ", ".join(profile["subjects"])
    ans = ask_ai(f"Create weekly study plan for {subjects} in simple English.")
    print("\n📚 Study Plan:\n", ans)
    display(speak("Here is your study plan."))
    return menu()

def quiz():
    sub = input("\nQuiz for which subject? ➡ ")
    ans = ask_ai(f"Generate 5 MCQs with answers for {sub}.")
    print("\n📝 Quiz:\n", ans)
    display(speak("Quiz ready!"))
    return menu()

def explain():
    topic = input("\nWhich topic to explain? ➡ ")
    ans = ask_ai(f"Explain {topic} in simplest form with examples.")
    print("\n✨ Explanation:\n", ans)
    display(speak("Explained the topic."))
    return menu()

def summary():
    print("\nPaste your notes to summarize:")
    text = input("➡ ")
    ans = ask_ai(f"Summarize:\n{text}")
    print("\n🧾 Summary:\n", ans)
    display(speak("Your summary is ready."))
    return menu()

# 🚀 Start App
start()
# Out:
# 👋 Welcome to ConsciousLearning!
# Which level?
# 1 School  2 College  3 Competitive Exams
# ➡ 2
#
# Enter subjects comma separated:
# ➡ English
#
# All Set! 🚀
#
# ========== ConsciousLearning ==========
# 1️⃣ Study Plan
# 2️⃣ Quiz Generator
# 3️⃣ Explain Topic
# 4️⃣ Summarize Notes
# 5️⃣ Exit
# =======================================
#
# Choose (1-5): 1
#
# 📚 Study Plan:
#  Hello! This is an easy plan to study English every week.
# Do a little bit each day. It's okay if you miss a day.
# Try to study for **20-30 minutes** each day.
#
# ---
#
# ### Simple Weekly English Study Plan
#
# **Monday: Learn New Words & Grammar**
# *   **Words (Vocabulary):** Learn 5 new words. Write them down. Say them aloud.
#     *   *Example:* book, read, table, sit, happy
# *   **Grammar:** Learn 1 easy grammar rule (like "to be" verb: I am, you are). Do 2-3 easy exercises.
#
# **Tuesday: Read & Listen**
# *   **Reading:** Read a very short, easy English story or a short text. Try to understand the main idea.
#     *   Find 2 new words from the text.
# *   **Listening:** Listen to an easy English song or a short beginner podcast (5-10 minutes). Try to catch familiar words.
#
# **Wednesday: Write & Speak**
# *   **Writing:** Write 3-5 simple sentences about your day or a simple topic (like your favorite food).
#     *   *Example:* "Today I woke up early. I ate bread. I feel good."
# *   **Speaking:** Talk to yourself in English for 5 minutes. Describe your room, your plans, or what you did yesterday.
#
# **Thursday: Repeat & Review**
# *   **Words (Vocabulary):** Review Monday's words. Learn 3 more new words.
# *   **Grammar:** Review Monday's grammar rule. Try to make 2 sentences using it yourself.
#
# **Friday: Fun English**
# *   **Reading:** Read something you enjoy! A short comic, a simple blog post, or a children's book.
# *   **Listening:** Watch a short cartoon or a simple English video (with English subtitles if you need).
#
# **Saturday: Practice Day**
# *   **Mix All:** Watch an English movie or TV show (with English subtitles). Try to understand the story.
# *   **Talk/Write:** If you can, try to talk to an English speaker. If not, write a longer paragraph (7-10 sentences) about your week.
#
# **Sunday: Relax & Review**
# *   **Review:** Look at all the new words and grammar you learned this week.
# *   **Relax:** No strict study today. Rest your brain. Maybe listen to some English music just for fun.
#
# ---
#
# ### Important Tips!
#
# *   **Be Patient:** English takes time. Don't worry about mistakes.
# *   **Make it Fun:** Choose topics you like.
# *   **Be Consistent:** A little bit every day is better than a lot once a week.
# *   **Don't Give Up!** You can do it!
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>
# ========== ConsciousLearning ==========
# 1️⃣ Study Plan
# 2️⃣ Quiz Generator
# 3️⃣ Explain Topic
# 4️⃣ Summarize Notes
# 5️⃣ Exit
# =======================================
#
# Choose (1-5): 2
#
# Quiz for which subject? ➡ English
#
# 📝 Quiz:
#  Here are 5 MCQs for English, covering different aspects like grammar, vocabulary, and literary devices:
#
# ---
#
# **1. Grammar: Subject-Verb Agreement**
#
# **Question:** Neither John nor his sisters _______ going to the party.
#
# a) is
# b) are
# c) was
# d) has been
#
# **Answer: b) are**
# *Explanation: When "neither/nor" connects two subjects, the verb agrees with the subject closest to it. In this case, "sisters" is plural, so the verb should be "are."*
#
# ---
#
# **2. Vocabulary: Contextual Meaning**
#
# **Question:** What is the closest meaning of 'exquisite' in the sentence: "The artist's painting was truly exquisite, admired by all"?
#
# a) Large
# b) Flawed
# c) Beautiful and delicate
# d) Expensive
#
# **Answer: c) Beautiful and delicate**
# *Explanation: 'Exquisite' means extremely beautiful and delicate, often implying a high degree of skill or craftsmanship.*
#
# ---
#
# **3. Literary Device**
#
# **Question:** Which literary device is used in the sentence: "The wind whispered secrets through the trees"?
#
# a) Simile
# b) Metaphor
# c) Personification
# d) Hyperbole
#
# **Answer: c) Personification**
# *Explanation: Personification is giving human qualities or actions (like whispering secrets) to inanimate objects or abstract ideas (like the wind).*
#
# ---
#
# **4. Punctuation**
#
# **Question:** Which sentence is correctly punctuated?
#
# a) She went to the store, and bought some milk.
# b) The dog wagged its tail; happily.
# c) Although it was raining, we decided to go for a walk.
# d) My favorite colors are, blue, green, and yellow.
#
# **Answer: c) Although it was raining, we decided to go for a walk.**
# *Explanation: A comma is needed after an introductory dependent clause (like "Although it was raining"). Options a and d have unnecessary commas, and option b uses a semicolon incorrectly.*
#
# ---
#
# **5. Idiom**
#
# **Question:** What does the idiom 'spill the beans' mean?
#
# a) To drop food on the floor
# b) To reveal a secret
# c) To make a mess
# d) To tell a funny story
#
# **Answer: b) To reveal a secret**
# *Explanation: The idiom "spill the beans" means to unintentionally or prematurely reveal confidential information or a secret.*
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>
# ========== ConsciousLearning ==========
# 1️⃣ Study Plan
# 2️⃣ Quiz Generator
# 3️⃣ Explain Topic
# 4️⃣ Summarize Notes
# 5️⃣ Exit
# =======================================
#
# Choose (1-5): 3
#
# Which topic to explain? ➡ Process of communication
#
# ✨ Explanation:
#  Imagine communication like throwing and catching a ball. It's how one person shares something with another person so they both understand.
#
# Here's the process in its simplest form, step-by-step:
#
# ---
#
# ### The Communication Process (Ball Game Analogy)
#
# 1.  **Sender (The Thrower):**
#     *   This is the person who has an idea, thought, or feeling they want to share.
#     *   **Example:** You see a funny meme and want to tell your friend about it. You are the **Sender**.
#
# 2.  **Message (The Ball):**
#     *   This is the actual information, idea, or feeling the sender wants to convey.
#     *   **Example:** Your thought is, "This meme made me laugh so hard!" That's your **Message**.
#
# 3.  **Encoding (Preparing the Ball):**
#     *   The sender takes their message and puts it into a form that can be understood. This means choosing words, tone of voice, gestures, or even writing it down.
#     *   **Example:** You decide to text your friend. You type: "OMG, you HAVE to see this meme! 😂" You've **Encoded** your message into text and emojis.
#
# 4.  **Channel (How the Ball Travels):**
#     *   This is the method or medium used to send the message. It could be talking face-to-face, a phone call, text message, email, body language, etc.
#     *   **Example:** The **Channel** you chose is a text message.
#
# 5.  **Receiver (The Catcher):**
#     *   This is the person who gets the message.
#     *   **Example:** Your friend gets the notification on their phone. They are the **Receiver**.
#
# 6.  **Decoding (Catching and Understanding the Ball):**
#     *   The receiver interprets and understands the message. They "decode" the words, tone, or gestures back into an idea in their own mind.
#     *   **Example:** Your friend reads your text, sees the emoji, and understands that you found a very funny meme. They have **Decoded** your message.
#
# 7.  **Feedback (Throwing the Ball Back):**
#     *   This is the receiver's response to the message. It lets the sender know if their message was understood correctly (or at all!). Feedback can be verbal (words) or non-verbal (a nod, a smile, a confused look).
#     *   **Example:** Your friend texts back: "LOL! Send it to me!" This is their **Feedback**, showing they understood and are engaged.
#
# ---
#
# ### Other Important Elements:
#
# *   **Noise (Obstacles):** Anything that interferes with the message being sent, received, or understood clearly.
#     *   **Example:** If your friend's phone battery died before they could send feedback, or if you accidentally typed a typo ("OMG, you HAVE to *bee* this meme!"), that's **Noise**. Or if you were talking in a noisy room.
#
# *   **Context (The Game Field):** The situation, environment, and relationship between the sender and receiver. This influences how messages are interpreted.
#     *   **Example:** Sending a formal email to your boss versus a casual text to your friend uses different **Contexts**, affecting your word choice and tone.
#
# ---
#
# ### In a Nutshell:
#
# You have a thought (Sender, Message), you put it into words/signs (Encoding), you send it (Channel), another person gets it (Receiver), they understand it (Decoding), and they react to it (Feedback). All of this happens amidst potential distractions (Noise) and in a specific setting (Context).
#
# The goal is always to make sure the message sent is the message received and understood!
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>
# ========== ConsciousLearning ==========
# 1️⃣ Study Plan
# 2️⃣ Quiz Generator
# 3️⃣ Explain Topic
# 4️⃣ Summarize Notes
# 5️⃣ Exit
# =======================================
#
# Choose (1-5): 4
#
# Paste your notes to summarize:
# ➡ Imagine communication like throwing and catching a ball. It's how one person shares something with another person so they both understand.  Here's the process in its simplest form, step-by-step:  ---  ### The Communication Process (Ball Game Analogy)  1.  **Sender (The Thrower):**     *   This is the person who has an idea, thought, or feeling they want to share.     *   **Example:** You see a funny meme and want to tell your friend about it. You are the **Sender**.  2.  **Message (The Ball):**     *   This is the actual information, idea, or feeling the sender wants to convey.     *   **Example:** Your thought is, "This meme made me laugh so hard!" That's your **Message**.  3.  **Encoding (Preparing the Ball):**     *   The sender takes their message and puts it into a form that can be understood. This means choosing words, tone of voice, gestures, or even writing it down.     *   **Example:** You decide to text your friend. You type: "OMG, you HAVE to see this meme! 😂" You've **Encoded** your message into text and emojis.  4.  **Channel (How the Ball Travels):**     *   This is the method or medium used to send the message. It could be talking face-to-face, a phone call, text message, email, body language, etc.     *   **Example:** The **Channel** you chose is a text message.  5.  **Receiver (The Catcher):**     *   This is the person who gets the message.     *   **Example:** Your
#
# 🧾 Summary:
#  The text describes communication as sharing understanding, using a ball game analogy. It outlines the process step-by-step:
#
# 1.  **Sender (The Thrower):** The person with an idea or feeling to share.
# 2.  **Message (The Ball):** The actual information or idea being conveyed.
# 3.  **Encoding (Preparing the Ball):** The sender puts the message into an understandable form (e.g., words, text, gestures).
# 4.  **Channel (How the Ball Travels):** The method used to send the message (e.g., text message, face-to-face talk).
# 5.  **Receiver (The Catcher):** The person who receives the message.
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>
# ========== ConsciousLearning ==========
# 1️⃣ Study Plan
# 2️⃣ Quiz Generator
# 3️⃣ Explain Topic
# 4️⃣ Summarize Notes
# 5️⃣ Exit
# =======================================
#
# Choose (1-5): 5
#
# Goodbye! Keep learning 🌟
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>
